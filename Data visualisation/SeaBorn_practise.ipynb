# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset= pd.read_csv("Preprocessed_PlacementInput.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
#NUMBER OF ROWS AND COLUMNS

# %%
dataset.shape
# Out:
# (215, 15)

# %%
# FOR ROWS
dataset.shape[0]
# Out:
# 215

# %%
#FOR COLUMNS
dataset.shape[1]
# Out:
# 15

# %% [markdown]
# #UNIVARIATE ANALYSIS

# %%
sns.distplot( dataset, hist=True , kde= True, kde_kws={ 'color': 'red'})
# Out:
# C:\Users\my pc\AppData\Local\Temp\ipykernel_1016\1420918651.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( dataset, hist=True , kde= True, kde_kws={ 'color': 'red'})
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1016\1420918651.py in ?()
# ----> 1 sns.distplot( dataset, hist=True , kde= True, kde_kws={ 'color': 'red'})
#
# ...

# %%
sns.distplot( dataset['ssc_p'], hist=True , kde= True, kde_kws={ 'color': 'green'})
# Out:
# C:\Users\my pc\AppData\Local\Temp\ipykernel_1016\3728301118.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( dataset['ssc_p'], hist=True , kde= True, kde_kws={ 'color': 'green'})
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %% [markdown]
# #BIVARIATE ANALYSIS: DISTRIBUTION PLOT
# here 'x' and 'y' axes are numerical columns and given by us.

# %%
sns.jointplot(x = 'ssc_p',y = 'salary',data = dataset)
plt.show()
#SCATTER PLOT

# %%
#HEAT MAP FASHION
sns.jointplot(x = 'ssc_p',y = 'salary',data = dataset,kind='hex')
plt.show()

# %%
sns.jointplot(x = 'ssc_p',y = 'salary',data = dataset,kind='kde')
plt.show()

# %%
#PAIR PLOT
sns.pairplot(dataset,hue = 'gender',palette = "husl")
plt.show()
# IT shows only the plot BETWEEN THE QUANTITATIVE COLUMNS FRPM THE DATASET

# %% [markdown]
# # FOR CATEGORICAL PLOT

# %%
sns.stripplot( x= 'ssc_b', y= 'ssc_p', data=dataset, jitter=True, hue= 'status')
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sns.stripplot( x= 'gender', y= 'ssc_p', data=dataset,hue= 'status')
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %%
sns.swarmplot( x= 'gender', y= 'ssc_p', data=dataset,hue= 'status')
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %% [markdown]
# # DISTRIBUTION OBSERVATIONS

# %%
sns.violinplot(x = "gender", y = "ssc_p", data = dataset)
plt.show()

# %%
sns.violinplot(x = "specialisation", y = "salary", data = dataset,hue="gender")
# Out:
# <Axes: xlabel='specialisation', ylabel='salary'>

# %%
sns.violinplot(x = "ssc_b", y = "ssc_p", data = dataset, hue="gender" )
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sns.boxplot(x = "ssc_b", y = "ssc_p", data = dataset,hue="gender" )
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sns.boxplot(x = "ssc_b", y = "ssc_p", data = dataset,hue="gender", orient ="h")
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sns.barplot(x = "ssc_b", y = "ssc_p", data = dataset, hue='gender')
# Out:
# <Axes: xlabel='ssc_b', ylabel='ssc_p'>

# %%
sns.countplot(x = "ssc_b",data = dataset, hue='gender')
# Out:
# <Axes: xlabel='ssc_b', ylabel='count'>

# %%
sns.pointplot(x = "ssc_p",y="hsc_b",data =dataset,hue='gender')
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_b'>

# %%
#FACTOR PLOT
sns.catplot(x = "ssc_p", y = "status", hue = "gender", kind = 'violin', col = "workex", row='degree_t', data = dataset);
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.regplot(x = "total_bill", y = "tip", data = df, ci=100)
sb.lmplot(x = "total_bill", y = "tip", data = df)
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('exercise')
sb.catplot(x = "time", y = "pulse", hue = "kind", kind = 'violin', col = "diet", data = df);
plt.show()

# %%
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('anscombe')
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"),order = 2)
plt.show()

# %%
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('anscombe')
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"))
plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
g = sb.FacetGrid(df, col = "time")
g.map(plt.hist,"total_bill")
plt.show()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
g = sb.PairGrid(df, hue= "species")
g.map(sb.scatterplot)
plt.show()

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
g = sb.PairGrid(df)
g.map(plt.scatter);
plt.show()
